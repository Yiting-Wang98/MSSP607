# %% [markdown]
# <a href="https://colab.research.google.com/github/Yiting-Wang98/MSSP607/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
spam=[2,4,6,8,10]
print(spam)
spam[2]=('hello')
print(spam)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4, 'hello', 8, 10]

# %%
letters=['a',  'b',  'c', 'd']
print(letters)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# ?int
letters[int(int('3'*2)//11)]
# Out:
# 'd'

# %% [markdown]
# ‘3’*2= '33', int() converts it to 33,
# int(33//11)means 33/11=3
# since letters[3] equals to the third number in the letters, and a=0,b=1,c=2,d=3;
# the answer is d

# %%
letters[-1]
# Out:
# 'd'

# %% [markdown]
# -1 refers to the last item in the list

# %%
letters[:2]
# Out:
# ['a', 'b']

# %%
:2 refers to the first and the second item in the list

# %%
list1=['a','b','c']
tuple1=tuple(list1)
print(tuple1)
# Out:
# ('a', 'b', 'c')

# %% [markdown]
# tuple() function converts a list into a tuple, and the list() function converts a tuple into a list.

# %%
list = ['apples', 'bananas', 'tofu', 'cats']
def spam1(list):
    first_part = ', '.join(list[:-1])
    last_part = list[-1]
    result = first_part + ', and ' + last_part
    return result
print(spam1(list))
# Out:
# apples, bananas, tofu, and cats
